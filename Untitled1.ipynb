# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\HP\Downloads\football_injury_dataset.csv', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#          Player Name  Age    Position               Club   Season  \
# 0       Lionel Messi   34     Forward                PSG  2021/22
# 1  Cristiano Ronaldo   36     Forward  Manchester United  2020/21
# 2          Neymar Jr   29     Forward                PSG  2022/23
# 3         Paul Pogba   28  Midfielder  Manchester United  2021/22
# 4    Kevin De Bruyne   30  Midfielder    Manchester City  2020/21
#
#      Injury Type        From       Until  Days Missed  Games Missed
# 0      Hamstring  10/09/2021  20/09/2021           10             2
# 1    Knee Injury  01/11/2020  18/11/2020           17             3
# 2   Ankle Sprain  15/12/2022  20/01/2023           36             6
# 3  Muscle Injury  25/10/2021  30/11/2021           36             5
# 4  Ligament Tear  20/01/2020  10/03/2020           50             8

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Define X and y for classification
df["LongTermInjury"] = (df["Days Missed"] > 21).astype(int)
y = df["LongTermInjury"]
X = df[["Age", "Position", "Club", "Injury Type"]]  # features

# One-hot encode categorical features
X = pd.get_dummies(X)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
pipeline = Pipeline(steps = 4)

# Categorical and numeric columns
categorical_cols = ["Position", "Club", "Injury Type"]
numeric_cols = ["Age"]

# Preprocessor for categorical columns
preprocessor = ColumnTransformer([
    ("onehot", OneHotEncoder(handle_unknown='ignore'), categorical_cols)
], remainder='passthrough')  # Keep Age as-is

# Final pipeline: preprocessing + model
pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", RandomForestClassifier(random_state=42))
])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, stratify=y, random_state=42 )

# %%
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, VotingClassifier, StackingClassifier, ExtraTreesClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier, ExtraTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier, NearestNeighbors
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, classification_report, confusion_matrix

# %%
rfc = RandomForestClassifier()
rfc_model = rfc.fit(X_train, y_train)
rfc_model
# Out:
# RandomForestClassifier()

# %%
print(classification_report(y_test, rfc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
lr = LogisticRegression()
lr_model = lr.fit(X_train, y_train)
lr_model
# Out:
# LogisticRegression()

# %%
print(classification_report(y_test, lr.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
abc = AdaBoostClassifier()
abc_model = abc.fit(X_train, y_train)
abc_model
# Out:
# AdaBoostClassifier()

# %%
print(classification_report(y_test, abc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
bc = BaggingClassifier()
bc_model = bc.fit(X_train, y_train)
bc_model
# Out:
# BaggingClassifier()

# %%
print(classification_report(y_test, bc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
lr = LogisticRegression(max_iter = 5000, random_state = 1)
nb = GaussianNB()
dtc = DecisionTreeClassifier()
vc = VotingClassifier(estimators = [('tree', dtc), ('linear', lr), ('naive', nb)])

# %%
vc_model = vc.fit(X_train, y_train)
vc_model
# Out:
# VotingClassifier(estimators=[('tree', DecisionTreeClassifier()),
#                              ('linear',
#                               LogisticRegression(max_iter=5000,
#                                                  random_state=1)),
#                              ('naive', GaussianNB())])

# %%
print(classification_report(y_test, vc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %%
sc = StackingClassifier(estimators = [('tree', dtc), ('linear', lr), ('naive', nb)])
sc_model = sc.fit(X_train, y_train)
sc_model
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_split.py:805: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# StackingClassifier(estimators=[('tree', DecisionTreeClassifier()),
#                                ('linear',
#                                 LogisticRegression(max_iter=5000,
#                                                    random_state=1)),
#                                ('naive', GaussianNB())])

# %%
print(classification_report(y_test, sc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
etsc = ExtraTreesClassifier()
etsc_model = etsc.fit(X_train, y_train)
etsc_model
# Out:
# ExtraTreesClassifier()

# %%
print(classification_report(y_test, etsc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
gbc = GradientBoostingClassifier()
gbc_model = gbc.fit(X_train, y_train)
gbc_model
# Out:
# GradientBoostingClassifier()

# %%
print(classification_report(y_test, gbc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %%
hgbc = HistGradientBoostingClassifier()
hgbc_model = hgbc.fit(X_train, y_train)
hgbc_model
# Out:
# HistGradientBoostingClassifier()

# %%
print(classification_report(y_test, hgbc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
dtc = DecisionTreeClassifier(criterion='gini',
    splitter='best',
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    min_weight_fraction_leaf=0.0,
    max_features=None,
    random_state=None,
    max_leaf_nodes=None,
    min_impurity_decrease=0.0,
    class_weight=None,
    ccp_alpha=0.0,
    monotonic_cst=None,)
dtc_model = dtc.fit(X_train, y_train)
dtc_model
# Out:
# DecisionTreeClassifier()

# %%
print(classification_report(y_test, dtc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
etc = ExtraTreeClassifier()
etc_model = etc.fit(X_train, y_train)
etc_model
# Out:
# ExtraTreeClassifier()

# %%
print(classification_report(y_test, etc.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
nb_model = nb.fit(X_train, y_train)
nb_model
# Out:
# GaussianNB()

# %%
print(classification_report(y_test, nb.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       1.00      0.50      0.67         2
#
#     accuracy                           0.67         3
#    macro avg       0.75      0.75      0.67         3
# weighted avg       0.83      0.67      0.67         3

# %%
knc = KNeighborsClassifier()
knc_model = knc.fit(X_train, y_train)
knc_model
# Out:
# KNeighborsClassifier()

# %%
print(classification_report(y_test, knc.predict(X_test)))
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\HP\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.fit_transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 1.65915912, -0.33333333,  0.65465367,  0.        , -0.5       ,
#          0.        , -0.33333333, -0.33333333, -0.33333333,  1.52752523,
#         -0.65465367, -0.33333333,  0.        ,  0.        , -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333,  3.        ,  0.        , -0.33333333, -0.33333333,
#         -0.33333333],
#        [-1.89618185, -0.33333333,  0.65465367,  0.        , -0.5       ,
#          0.        ,  3.        , -0.33333333, -0.33333333, -0.65465367,
#         -0.65465367, -0.33333333,  0.        ,  0.        , -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333,  3.        ,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333],
#        [ 0.        ,  3.        , -1.52752523,  0.        , -0.5       ,
#          0.        , -0.33333333, -0.33333333, -0.33333333,  1.52752523,
#         -0.65465367, -0.33333333,  0.        ,  0.        , -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#          3.        ],
#        [ 0.23702273, -0.33333333,  0.65465367,  0.        , -0.5       ,
#          0.        , -0.33333333,  3.        , -0.33333333, -0.65465367,
#         -0.65465367, -0.33333333,  0.        ,  0.        , -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#          3.        , -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333],
#        [-0.23702273, -0.33333333, -1.52752523,  0.        ,  2.        ,
#          0.        , -0.33333333, -0.33333333, -0.33333333,  1.52752523,
#         -0.65465367, -0.33333333,  0.        ,  0.        , -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333,  3.        ,
#         -0.33333333],
#        [ 0.        , -0.33333333,  0.65465367,  0.        , -0.5       ,
#          0.        , -0.33333333, -0.33333333, -0.33333333, -0.65465367,
#          1.52752523, -0.33333333,  0.        ,  0.        ,  3.        ,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333],
#        [-1.42213639, -0.33333333,  0.65465367,  0.        , -0.5       ,
#          0.        , -0.33333333, -0.33333333, -0.33333333, -0.65465367,
#          1.52752523, -0.33333333,  0.        ,  0.        , -0.33333333,
#         -0.33333333,  3.        ,  0.        , -0.33333333, -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333],
#        [ 1.18511366, -0.33333333,  0.65465367,  0.        , -0.5       ,
#          0.        , -0.33333333, -0.33333333, -0.33333333, -0.65465367,
#          1.52752523, -0.33333333,  0.        ,  0.        , -0.33333333,
#         -0.33333333, -0.33333333,  0.        ,  3.        , -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333],
#        [ 0.23702273, -0.33333333,  0.65465367,  0.        , -0.5       ,
#          0.        , -0.33333333, -0.33333333, -0.33333333, -0.65465367,
#         -0.65465367,  3.        ,  0.        ,  0.        , -0.33333333,
#          3.        , -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333],
#        [ 0.23702273, -0.33333333, -1.52752523,  0.        ,  2.        ,
#          0.        , -0.33333333, -0.33333333,  3.        , -0.65465367,
#         -0.65465367, -0.33333333,  0.        ,  0.        , -0.33333333,
#         -0.33333333, -0.33333333,  0.        , -0.33333333, -0.33333333,
#         -0.33333333, -0.33333333,  0.        ,  3.        , -0.33333333,
#         -0.33333333]])

# %%
from sklearn.decomposition import PCA
pca = PCA()
X_train_pca = pca.fit_transform(X_train_scaled)

# %%
pca = PCA(n_components = 10)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
X_train_pca.shape
# Out:
# (10, 10)

# %%
lr = LogisticRegression(max_iter = 3000, random_state = 1)
lr.fit(X_train_pca, y_train)
# Out:
# LogisticRegression(max_iter=3000, random_state=1)

# %%
print(classification_report(y_test, lr.predict(X_test_pca)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         3
#    macro avg       1.00      1.00      1.00         3
# weighted avg       1.00      1.00      1.00         3

# %%
import joblib
joblib.dump(pipeline, 'injury_risk_model.pkl')
# Out:
# ['injury_risk_model.pkl']
